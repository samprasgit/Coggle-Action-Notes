# %% [markdown]
# # 背景介绍
# 意图识别（Intent Recognition）是指通过自然语言文本来自动识别出用户的意图或目的的一项技术任务。在人机交互、语音识别、自然语言处理等领域中，意图识别扮演着至关重要的角色。
#
# 意图识别有很多用途，例如在搜索引擎中分析用户的核心搜索需求，在对话系统中了解用户想要什么业务或者闲聊，在身份识别中判断用户的身份信息等等。意图识别可以提高用户体验和服务质量。

# %% [markdown]
# # Task1 数据读取与分析
# NLP是自然语言处理的缩写，是研究如何让计算机理解和处理自然语言的一门技术。自然语言是人类交流和表达思想的主要工具，具有丰富的语义和多样的形式。学习NLP需要掌握基本的语言学概念、文本预处理和文本表示方法等基础知识。语言学概念可以帮助我们分析自然语言的结构和规律，文本预处理可以帮助我们清洗和规范化文本数据，文本表示方法可以帮助我们将文本转换为计算机可处理的数值向量。
#
# 学习NLP很难的原因可能有以下几点：NLP涉及多个领域的知识，需要有较强的综合能力和自学能力；NLP是一个快速发展的领域，需要不断更新自己的知识和技能；NLP面临很多挑战和难题，如自然语言的歧义性、复杂性、多样性等。
#
# - 步骤1：下载意图识别数据集，该数据集是一个多分类任务，目标是根据用户的输入文本判断用户的意图。意图识别数据集的加载方法如下代码。
# - 步骤2：使用Pandas库读取数据集，Pandas是一个用于数据分析和处理的Python库，可以方便地读取、操作和保存各种格式的数据文件。使用Pandas的read_csv函数可以读取csv格式的数据文件，并返回一个DataFrame对象。
# - 步骤3：统计训练集和测试集的类别分布、文本长度等基本信息，以了解数据集的特征和难度。使用DataFrame对象的value_counts函数可以统计每个类别出现的次数和比例，使用apply函数和len函数可以统计每个文本的长度。
# - 步骤4：通过上述步骤，请回答下面问题
#     - 数据集的文本长度分布一致吗？
#     - 数据集中的文本是长文本还是短文本？根据统计结果，查看每个文本的长度分布情况，如文本长度的中位数。
#     - 数据集中总共包含了多少个字符，多少个单词？将单词按照意图类别绘制云图。

# %%
# 读取数据集，这里是直接联网读取，也可以通过下载文件，再读取
import pandas as pd

data_dir = 'https://mirror.coggle.club/dataset/coggle-competition/'
train_data = pd.read_csv(data_dir + 'intent-classify/train.csv', sep='\t', header=None)
test_data = pd.read_csv(data_dir + 'intent-classify/test.csv', sep='\t', header=None)

#  统计训练集的Intent分布
print(train_data[1].value_counts())
print(train_data[1].unique())
# 统计训练集的文本长度分布
print(train_data[0].apply(len).describe())
# Out:
# 1
# FilmTele-Play            1355
# Video-Play               1334
# Music-Play               1304
# Radio-Listen             1285
# Alarm-Update             1264
# Weather-Query            1229
# Travel-Query             1220
# HomeAppliance-Control    1215
# Calendar-Query           1214
# TVProgram-Play            240
# Audio-Play                226
# Other                     214
# Name: count, dtype: int64
# ['Travel-Query' 'Music-Play' 'FilmTele-Play' 'Video-Play' 'Radio-Listen'
#  'HomeAppliance-Control' 'Weather-Query' 'Alarm-Update' 'Calendar-Query'
#  'TVProgram-Play' 'Audio-Play' 'Other']
# count    12100.000000
# mean        15.138678
# std          4.872583
# min          4.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         54.000000
# Name: 0, dtype: float64

# %%
# 统计字符数
char_count = train_data[0].str.len().sum()
print("train data 字符数：",char_count) 
# 统计单词数
word_count = train_data[0].apply(lambda x: len(x.split(' '))).sum() 
print("train data 单词数：",word_count)
# Out:
# train data 字符数： 183178
# train data 单词数： 12195

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot  as plt 
import jieba 


# 中文分词
content = ''.join(train_data[train_data[1]=='Music-Play'][0])
print(content)
words = jieba.lcut(content) 

# 读取中文停用词
cn_stopwords = ''.join(pd.read_csv('https://mirror.coggle.club/stopwords/baidu_stopwords.txt', header=None)[0])
words = [x for x in words if x not in cn_stopwords]

# 中文字体，https://mirror.coggle.club/STHeiti-Light.ttc
# 手动下载中文字体到当前代码目录 
wordcloud = WordCloud(background_color = 'white', max_words = 1000, font_path = 'STHeiti-Light.ttc')
wordcloud.generate(' '.join(words))
plt.imshow(wordcloud)
plt.xticks([]); plt.yticks([])
# Out:
# 随便播放一首专辑阁楼里的佛里的歌单曲循环一首催眠的歌吧播放钢琴曲命运交响曲我要听治愈系的日语歌曲我一定要单曲循环赵雷的我们的时光这首流行播放一首适合开心时候听的歌曲呢我想听顽童的辣台妹能播放一下不2011年最浪漫的歌来一首呗来放一个德语歌曲给我吧播放日语歌泪的物语请给我来一首吴亦凡的英文歌July。循环播放张哲瀚的环绕吧请播放带戏曲唱腔的专辑赤伶，李玉刚版的一定循环播放我们的时光这首流行呼吸之野里的歌曲随便来一首播放一下吧法语歌曲可以随机来一首不可以随机给我来一曲山河令电视剧里面的歌呢90年代比较搞笑的歌曲来一些听听放一首扬琴版的梁祝给我找一首蔡琴的歌听听我想播放张信哲的下一个永远中的白月光想听最好的都给你了，要余佳运给我唱能给我来一个2021年的古典音乐不呢想听英文专辑了，就第stay with you吧，林俊杰的完美降落播放，法老他们合唱的随机播放一首纯音乐。请按随机播放一首张杰的中文歌曲播一首运动风格的中文歌曲初爱里面的歌可以随机唱一首吗林俊杰的专辑乐行者随机播放吧治愈系的钢琴曲能随便来个听吗顺序播放李健的歌曲1999年发行的歌都播放一遍呢随机来一首欢快一点的浪漫情歌吧来一首差一步里的歌儿播放一首应景儿的《回到拉萨》，我要郑钧的银临、河图的专辑蚍蜉渡海播放我想听金莎唱的爱的魔法这首流行音乐我需要你来一首许嵩的认错呢我要陈小熊的歌儿 济南济南吧请播放吴涤清版的《梅兰梅兰我爱你》放一首萨克斯演奏的古典音乐我想听英文的情歌呢顺序播放周杰伦的专辑七里香里面的歌这一生关于你的风景，我要听隔壁老樊唱的我想你给我播放一首表达爱意的钢琴曲呢单曲循环一下名侦探柯南里面的主题曲吧黄安90年代的歌随机来一首可以吗二胡弹奏的人气高的歌曲来一首呢有没有比较热血的动漫配乐给我来一首吧按顺序播放专辑Wuha里的歌曲2000年左右的歌曲给我随机来一首播放齐秦的大约在冬季你能给我放范丞丞的快乐很简单吗是不是能单曲循环一下你不知道的事放一下BEYOND的经典光辉岁月随机来一首2011年的歌听一下张国荣光荣岁月里面的歌吧还是想循环播放流行风格的专辑放一首rap，放十全九美随机播放一首李冠森的歌曲立刻播放萧忆情的拜无忧来一首2009年王力宏的曲子吧把悲伤留给自己单曲循环播放帮我找蔡徐坤的情人播一下第二街区这张专辑里的第一首循环放给我听Bieber的justice来毛不易像我这样的人我要听周深和王子一起唱的资深庸才日本歌手米津玄师的日语歌随机来一首呗2007年王力宏的我们的歌播放一下吧想听古筝了，来一首铁马吟听听天韵霍尊里的歌曲现在随机来一首呢你可以播放一下凤凰传奇的快乐的音乐吗播放屠洪刚的专辑风云2里面的歌曲有中国娃娃的恭喜恭喜就放一下随机播放韩红的歌单曲循环一个钢琴曲可以吗老歌手刀郎的歌来几首吧给我唱一个开心的阿拉伯语歌曲呢播放hold on，Bieber唱的啊我想听任同祥的唢呐曲到春来随机播放一首暗杠里的歌曲韩语歌随机来一首吧俄语歌有没有比较治愈的放一个我现在就想听一下郎朗的钢琴曲呢能不能听一下继续张国荣这张专辑里的歌曲，随机来一首就行来一首90年代的英文歌呗播放笙演奏的冬猎周杰伦的叶惠美可以顺序播放吗播放林依晨的流行歌非你莫属呼吸之野里面的假摔单曲循环一下吧我想你给我播放胡彦斌的专辑太歌里的歌呢唱一首英文流行歌曲呢王菲和陈奕迅的合唱歌曲传奇播放一下给我把凤凰传奇的歌顺序播放吧最近比较火的孤影单曲循环吧请随机播放一首钢琴曲。有没有什么听了就想笑的的德语歌有没有新的适合表白氛围的歌曲播放一下啊陈鸿宇的步履不停里面的歌曲随机来一首呢我想要一首很治愈的德语歌听你可以找一下2020年最人气的歌曲给我播放吗来一首钢琴弹唱的勇气随机来一首张国荣的歌曲可以吗隔壁老樊的我曾放到按照顺序播放下周就要歌唱比赛了，我要单曲循环唱支山歌给党听。我还想继续听民谣南方姑娘我要学韩语，随便放一首随机播放陈一发专辑童话镇里的歌儿随机来一首2013年发行的英语歌随机来一首陈旭的歌曲可以吗我想听一首陈泓宇步履不停里面的歌曲啊现在想听80年代的英文歌你有搞笑的英文歌给我播放吗2021年新发行的爵士歌曲随机来一个呢来一首八十年代潘美辰的《我想有个家》听听给我随机播放一首70年代的英文歌曲有什么歌曲是葫芦丝创作的，按顺序播放我想听一听咯是不是可以来一首90年代的英文歌给我呢网络歌曲开业大吉播放周杰伦的2011年的歌曲播放一下可以吧播放轻音乐琵琶语我要听赵雷的成都。单曲播放霄磊的叹郁孤由低苦艾乐队演唱的兰州兰州快帮我播一下随机来一首薛之谦的歌曲吧kiss me baby这个英文歌是流行音乐中很火的一曲你能找一个90年代的欢快歌曲给我听听不你能不能帮我播放一个德语歌曲啊一直给我循环甜蜜蜜可以吗唱一首80年代的古典歌曲给我听听给我放张雨生的大海忽然想到琵琶弹的十面埋伏，立即播放我让你给我放一首90年代德语歌曲呢来一首黄丽玲的她说洗澡的时候给我来一首李荣浩的年少有为。找一首王梓作曲的五十年代的歌曲按照顺序播放一下鸽子里的所有歌曲呢可以给我顺序播放一下林俊杰的乐行者吗我想要听俄语的民谣乐曲播放摇滚啊，假行僧找一首颜人中的歌儿听钢琴曲有适合睡觉听的吗，来一首吧顺序播放邓紫棋倒数专辑放一首周杰伦的晴天今天适合听有多少爱可以重来，来摇滚版的吧来一首兴奋的纯音乐给我欣赏一下呢随便放一首那英或者田震的歌儿把周杰伦的告白气球播放一下我要听民谣曾经的你你帮我找一首当前最火的电视剧的主题曲听听我想要听一首热血一点的法语歌呢想听洞箫演奏的我是不是你最疼爱的人邓紫棋翻唱的手心的蔷薇打开听会儿随机听一首许嵩前些年写的歌吧现在听周深的起风了比较有感觉sold out播放，hawk nelson的英文摇滚我想听贝多芬的古典钢琴曲21世纪最火的歌立刻给我播放呢我想听一下郎朗的钢琴曲呢陈奕迅演唱会唱的歌给我随机来一首吧今年都有什么好听的古典乐播放几首吧我要听英文版的我的梦。近期有没有火爆的歌曲，随机来一首吧我想听张国荣的音乐呢播放Beyond的海阔天空。我想听80年代的中文歌曲顺序播放许嵩的歌曲吧可以给我听一个今年新发的古典乐么2019年的搞笑歌曲随便来一首听听我想要听朝九晚五里的歌，按顺序播放就行我命令你单曲循环不加糖能播放一下过去现在时这个专辑里面的歌吗我还是成龙这个专辑里的歌随机来一首听听呢穿过你的黑发的我的手放一下，要罗大佑版的帮我来一首2021年的专辑步履不停里面的歌曲吧顺序播放合唱专辑Génération Goldman里的歌现在来一首2021年的专辑步履不停内的歌呢随机播放一首爵士曲。可不可以放一些与南山南类似的民谣呢能把薛之谦的歌全部顺序播放一遍吗美国新出的英文歌曲可以来一首不呢日语唱的爵士乐来一首吧播放说唱歌曲慢热单曲循环Hey Jude这首民谣是不是可以来一首张国荣的粤语歌曲呢唱一首歌给我吧，要听英文版的情歌呢你能给我唱一个2011年的爵士乐吗给我找一首浪漫的德语歌曲随机来一首运动时候听的歌曲我要听日不落的钢琴曲。王一博的无感在哪里可以听啊快帮我播放一下请播放网络歌曲请不要在秋天失恋做胎教的音乐播放手舞足蹈麻烦给我单曲循环张艺兴的会好的。你现在就给我放一下真爱里面的歌，随便一个就行周杰伦唱的不能说的秘密能不能单曲循环播放呀你能立刻找一首搞笑的英文歌给我听吗你可以把邓紫棋的泡沫放给我听不我正在循环播放星辰大海是不是可以随机来首薛之谦的歌单曲循环菠萝菠萝蜜胡彦斌的大一号里的歌曲随机来一首你给我随机唱一首邓紫棋的歌吧90后都听什么流行歌曲，给我随机播放一个啊单曲循环薛之谦的像风一样2021年黄安传灯里的歌曲随机来一首吧循环播放大鹏的都选C帮我随机来一首林俊杰2011年的歌吧能来一首黄安专辑里面的女儿吗钢琴曲莫扎特的来一首呗我要听赵雷的鼓楼2020年快手最人气的歌曲唱一下呢二胡弹奏的曲子有没有人气比较高的来一首你能播放一些2020年比较浪漫的歌曲吗请播放摇滚歌曲再谈记忆放一首葫芦丝吹出来的古典乐随机来几首纯音乐吧你能唱一首90年代的经典歌曲给我么放点儿轻音乐，故乡的原风景吧顺序播放薛之谦专辑尘华晨宇的专辑新世界现在能听吗去年有没有搞笑的歌唱一下给我听一下李云迪弹奏的钢琴曲吧找一下黄安的《新鸳鸯蝴蝶梦》播放播放一下华晨宇的烟火里的尘埃吧华晨宇唱过的歌随机来一首吧我需要你给我来一首好听的90年代经典德语歌呢能不能随机来一首古筝弹奏的歌曲呢随便来一首寻宝游戏里面的歌曲呢我还想听韩红的青藏高原这种经典歌曲请播放2021年发行的专辑我们的主打歌2播放王一博的新专辑无感顺序播放姐姐、孤独的人是可耻的、蚂蚁三首歌立即播放孙燕姿的克卜勒单曲循环一首可可托海的牧羊人随机来一首盖世英雄里的歌曲呢给我顺序播放一下林俊杰专辑的因你而在开始播放孙语赛的专辑不仅仅是喜欢Private Corner里面的歌曲随机来一首啊麻烦放一下一场游戏一场梦，要王杰唱的那个放一下九十年代的《再回首》听听播放腾格尔天堂的现场版找一首花粥的经典听2007年出来的电视剧的片头曲来一首吧来个听了让人想哭的英文歌吧好想听张国荣的沉默是金播放汪峰的广安广安今年点击率最高的英文歌曲唱一下呢我现在比较喜欢听英文摇滚类的音乐，快帮我播放吧我需要一直随机播放薛之谦的歌呢给我听一会归一里的歌曲呢爵士歌曲能随机一首给我吗你给我听一首有点年代感的古典歌曲听听赵英俊的送你一朵小红花快帮我播放周杰伦的稻香我要听一首薛之谦的认真的雪可以吗我一直单曲循环赵雷的民谣成都想听《只要你过得比我好》了，要钟镇涛版来一首00年代的韩文歌给我播放一首抖音歌曲可以吗现在把周杰伦的歌都给我顺序播放一下吧可可托海的牧羊人可以给我单曲循环吗我想你给我播放几首金莎的二零零几年的歌呢播放高丽霞的歌儿一壶老酒2000年有没有治愈的英文歌听放一首张叶 ...
# ([], [])

# %% [markdown]
# # Task2：正则关键词与文本分类
# 正则表达式（Regular Expressions，简称regex）是一种用于字符串搜索和操作的强大工具。它使用单个字符串来描述、匹配一系列符合某个句法规则的字符串。正则表达式在计算机科学、编程、数据挖掘和文本处理中有着广泛的应用。
#
# - **定义规则**：根据分类需求，定义一组正则表达式规则。
# - **预处理文本**：对输入文本进行清洗，如去除标点符号、转换为小写等。
# - **模式匹配**：使用正则表达式在文本中搜索定义的模式。
# - **分类决策**：根据匹配结果，将文本分配到相应的类别。
#
# 使用正则表达式进行文本分类时，确定关键词是一个关键步骤，因为它直接影响到分类的准确性和效率。可以从分析中找出每个类别的高频词汇，或考虑类别相关的专业术语或行业特定的词汇。

# %%
# 关键词词典构建
from collections import Counter 
import re 
import string 


def to_patterns(template="Music-Play"):
    content = ''.join(train_data[train_data[1]== "Music-Play"][0])
    # 使用正则表达式去除所有空格、换行符和标点符号
    # 将所有的标点符号加入到正则表达式中
    punctuation = re.escape(string.punctuation) + "，。" # 对特殊字符进行转义

    # 创建正则表达式以匹配所有空格、换行符和标点符号
    content = re.sub(f'[{punctuation}\s]', '', content)

    words = jieba.lcut(content) 
    # 读取中文停用词
    cn_stopwords = ''.join(pd.read_csv('https://mirror.coggle.club/stopwords/baidu_stopwords.txt', header=None)[0])
    words = [x for x in words if x not in cn_stopwords]
    
    word_counts = Counter(words)
    
    df_music = pd.DataFrame(columns=["word", "word_count"])
    df_music["word"] = list(word_counts.keys() )
    df_music["word_count"] = list(word_counts.values()) 
    df_music = df_music.sort_values(by=["word_count"], ascending=False) 
    df_music[df_music['word_count'] >=10]
    music_pattern = r"(" + "|".join(df_music['word'].tolist())  + ")"
    return music_pattern
     
music_pattern = to_patterns(template="Music-Play")  
music_pattern
# Out:
# '(播放|一首|听|歌曲|随机|循环|歌|放|想|专辑|单曲|一个|唱|年代|顺序|钢琴曲|听听|找|90|随便|《|请|立刻|周杰伦|有没有|民谣|我要|日语|治愈|英文歌|薛之谦|林俊杰|歌儿|这首|抖音|演奏|许嵩|音乐|爱|2020|版|适合|主题曲|很|英文版|古典音乐|2021|传奇|古典|纯音乐|几首|英文歌曲|凤凰|2011|搞笑|弹奏|发行|欢快|德语|去年|都|张国荣|电视剧|英文|摇滚|爵士乐|版本|爱情|法语|火爆|古风|合唱|人气|2000|经典|最火|浪漫|曲子|想要|麻烦|胡彦斌|首歌|世纪|来首|邓丽君|二胡|播|80|英语|中国|曲|邓紫棋|古筝|、|钢琴|好听|就行|轻音乐|金曲|俄语|韩语|快|神曲|悲伤|睡觉|李荣浩|黄安|古诗|舞曲|喜欢|歌单|2019|火|一会|2014|老歌|陈奕迅|周深|游戏|情歌|一点|老师|歌来|寻宝|姑娘|歌给|赵雷|REVISIT|创作|莫扎特|70|风|张学友|演唱|诗|唱的歌|中文歌曲|山河|找到|赵英俊|古筝曲|送|小红花|英语歌|西班牙语|一朵|2009|最新|流行歌曲|时光|月|一首歌|乐|鸽子|梦|快乐|新歌|贝多芬|华晨|内|一曲|1999|新出|蔡依林|七十年代|大海|运动|张杰|九十年代|2016|唱歌曲|怀旧|流行歌|泷|宇|汪苏|王菲|莫文蔚|成都|近期|那英|张碧晨|三旬|韩文|经典歌曲|粤语|传灯|大鱼|步履|告白|气球|翻唱|歌唱|21|不停|é|归一里|萨克斯|李健|笛子|歌手|不易|名曲|毛|海底|王力宏|吻别|流行|肯定句|一遍|开心|挨着|真的|情绪|放个|民族|比伯|贾|唯|陈|流行音乐|难忘|斯汀|打开|日文|今宵|肖战|水手|甜蜜蜜|麻雀|张雨生|弹|热血|伤感|柯南|歌能|插曲|点播|忐忑|希望|兴奋|卡农|琳娜|龚|一生|法语歌|我爱你|不有|小时|2008|恋人|忒|影视|月亮代表|烟火|尘埃|中文|对不起|三|孙燕姿|可可托海|牧羊人|懂|巴乌|版来|雪|花粥|演员|走|呼吸|覅|不错|跳舞|月亮|吻|南|山南|风格|陈小春|完美|女儿|王一博|女人|泡沫|张信哲|霍尊|山海|选|丝竹|睡|春晚|弹唱|八十年代|阿拉伯语|爵士|回家|推荐|猫|2013|张韶涵|歌听|励志|两棵树|外来|草原|蔡|顶顶|郎朗|徐坤|情人|这张|听首|氛围|马上|笑|放给|故事|太歌|叶惠美|二泉映月|快点儿|长|接下来|琵琶|2015|韩红|古代|唱片|网络|杨宗纬|葫芦丝|岁月|年发|2017|不知|民歌|荒野|海洋|那首|00|钢琴演奏|嘉宾|苏打|酒|绿|相思|2018|播放歌曲|郑智化|红色|跨国|爱丽丝|归内|纯|蝴蝶|子|歌想|小城|出道|西口|玩乐|小品|大师|红日|凉凉|停|哆|丑八怪|A|歌词|初爱里|安徒生|大提琴|LIVE|珠帘|君|三十六计|卷|小孩|赶紧|李克勤|谭咏麟|徐佳莹|金莎|李清照|专业|埙|迟迟|二胡曲|十分钟|世界|郑容|温柔|吹|余年|Letitgo|两个|周传雄|拯救|找个|奈何|萨|英语版|歌行|小说|欢乐|小虎队|任意|刘若英|任贤齐|刘德华|死|阿拉伯|上个世纪|五月天|荷塘月色|20|宝贝|语言|陈粒|修炼|KTV|复出|粥|吉他|校园|摇滚乐|小夜曲|男|17|梅艳芳|60|藏语|潘玮柏|绝迹|公司|小提琴|高山流水|地球|很多|影后|一无所有|零|余生|青年|王维|段奕宏|过火|路|物|炫|心情|李宗盛|沈文裕|马思|生命|乡村音乐|歌放|李云迪|点击率|就要|不为|遇见|18|失眠|童话|首任|南方|好像|广安|兰州|程响|勇气|陈鸿宇|一整天|早点|之野|李白|笙|乐队|我播|听任|洞箫|10|新发|海阔天空|演唱会|感觉|小鬼|蔷薇|手心|打算|我会|欣赏|晴天|倒数|印象|五十年代|明天|少有|十面埋伏|七月|恭喜|蹦|扬琴|一步|翅膀|隐形|乐行者|恩情|永远|大地|1984|李玉刚|听说|经典音乐|如约|环绕|张哲瀚|July|吴亦凡|交响曲|催眠|应景|银临|2|随即|爱人|吟|2007|日本|白居易|充满|公子|爵士音乐|挨个儿|河图|侦探|名|隔壁|风景|七里香|梅兰|济南|认错|成龙|沈以诚|情|秘密|摇滚歌曲|秋天|一场|手|rationGoldman|星辰|哭|青藏高原|尘|可不可以|现场版|分手|列表|天空|日不落|王杰|PrivateCorner|罗大佑|G|汪峰|孤独|故乡|盖世英雄|快点|无感|新专辑|日月|下雨|上铺|太软|1998|四|澎湃|云白里|爆笑|清平调|爱过|眨眼|星座|过河|少年|夸张|搜索|小马|童年|表情|学到|心中|杨俊毅|孩子|空|当晚|莲佩姬|台上|曾用|谈何容易|印子|飞翔|简短|自由|音乐吧|打招|唿|赢得|几个|晚上|结婚|刚|萧亚轩|弹得|台下|向北走|阵阵|鬼|掌声|黑色|害怕|于波|兴华|段|兼|帅哥|贵妃醉酒|忘|相识|起点|篱笆|邰正宵|王可|九百九十九|对话|JW|五音|传|唐人|袁立|不良少年|徐威|开唱|一九九三年|奶爸|物里|朵玫瑰|千千|莲花|阕|陈慧娴|异界|九死|神功|佛教|之破|茧|听行|成蝶|一千零一夜|走马|怪|七叔|咖|不王|建隆|这份|名单|第九个|山丘|唯一|兄弟|越过|跌破眼镜|BIGBIGWORLD|甄子丹|刘惜|原唱|姜云升|withyou|踏|吴彦祖|最爱|星空|随波逐流|神|做梦|老婆|醒|国王|剪影|停工|一年|寡妇|假装|珠江|马头琴|编曲|陈琳|九泉之下|想起|机会|予卫诗|落霜|纵身|应否|AH|一朵花|牛头不对马嘴|回答|卓依婷|宋捷|徐远书|念旧|笑脸|梅花|活得|明灯|精灵|重现|王昌龄|昨日|跨过|蜀|体面|文文|remember|戏内|才|更好|同桌|秋水伊人|重逢|首范世|阳春白雪|再度|倾倒|偶像|不敢相信|一刻|有个|郭富城|天心|费玉清|千里|陈友|的确|海岛|30|鹊桥|仙请|著名|瞬间|勇敢|装在|套子|金钟|拿下|心刚|放得|老狼|美人鱼|王易阳|火海|呐看|琴伤|攻美|千|宝儿|子规|啼|好久不见|刘子|一路|封刀|认了|蓝|峥嵘|漆|泸沽湖|花落|推|首张|杨|大碟|发高烧|B2ER|歪嘴|扶|潼|黄诗|錡|表演|好笑|交换|摆头|王国|柚|王祖|那版想|哪见|狂奔|基督教|城市|再放|极品|落海|诸侯|戏|子行|初学者|伊能静|请播|七仙女|踏浪来|一下下|诗人|烽火|晚报|雅俗共赏|说好|送别|微微|现场|诗麻园|傅如乔|夜莺|童话故事|庸人自扰|王理文|克拉玛依|取消|力撑|小白|停止|抓得|拐杖|古天乐|之间|言语|田螺|寓言|老舅|宝石|痛仰|强忍|乐给|小姐|董|东野|宋|入睡|快速|回来|刘大壮|貌似|疼痛|夜宿|草|守护神|十二生肖|三少|唐家|开放|聊天|格拉|苏|收藏|爆满|蓝色|场场|巡演|二零场|六个月|持续|一九八九年|江上|公主|讲|山寺|阿楚|斯威夫特|姐妹|惺惺相惜|阮经天|家庭|拥有|心愿|汤|收下|新年快乐|迟|张惠妹|取名|经营|lanterns|峨眉山|放首|脸上|摆在|两种|努力|继父|TY|早期|梁凡|妈妈|有何不可|活着|郝云|眼泪|无所谓|欠|青溪|西给|驻马店|南拳|即可|不遇|隐者|播寻|美的|周炫|第一|排行榜|两年|侯佩岑|泰勒|lovestory|约翰|黄鹤楼|力度|霸气|美|惊天动地|美得|第一次|赞叹|有人|乌鸦|呗播|歌仙|压力|票债|容祖儿|舒缓|十场|增|大事|飘|样子|女孩|我终|二零|十年怕井绳|小芳|payback|Furious7|电影|安眠药|药|蒙汉|阳光|掩不住|咬|难看|蛇|一朝|到底|长恨歌|春天里|年于|椿|一支|忆江南|多岁|听到|刘禹锡|李俊基|一吻|泰国|有幸|狼|杀破|广播剧|红颜|14|沙一汀|傻瓜|安卓|yoursoul|小可爱|听凤鸣|胡广生|乡村|素汐|小气|仇人|洞庭|定情|美化|可怕|郭峰|有时候|固执|台|菊花|形象|男人|善良|安全感|爱放|中期|萌|塞下曲|咏鹅放|骆宾王|大道|日落|混合体|MUSIC|萌阿妆|出水|莱顿|福斯特|演播|IPHONE|过头|听会|lover|忧伤|马頔|电子琴|蝉|飞鸟|五好|一块|好强|带上|弟妹|老姜|玩若行|地方|有空|今晚|一视同仁|好会轻|余电|名歌|高晓松|海|表现|郑元畅|演戏|飞鸟集|泰戈尔|山止川行|散步|不是冤家不聚头|清明|那片|蒙古人|儿放|Cetrainquisenva|ReasonableDoubt|第一张|JayZ|升级包|零七|九|I|态度|何江涛|入戏|唱首|惹|一位|最强|唱功|公认|十强|李行亮|岁|二七|高跟鞋|张宇|蔡健雅|独酌|非花|千玺|烊|联欢晚会|春节|跑|绕|祸|中有|入耳|印记|蝉鸣|声声|摇曳|树枝|窗外|午后|夏日|老人与海|海明威|精彩|试听|相依为命|迟到|张行|冰|千纸鹤|离去|拥抱|北|张北|洒脱|不咸不淡|安娜|蘑菇|沙丘|徐晓萍|醉酒|那版|深秋|白帝城|早发|金针菇|香菇|展现|不停息|平时|只不过|一部分|身上|项羽|昔日|拜祭|访港|念旧情|杨美华|塞北|近藤|学校|亚丽|原名|阿普|阿丽|善解人意|女孩儿|书生|麻辣|学生上课|出口|李俊|早些|爱能|门外|站|打到|收音机|母亲|父亲|熹像|真彦|飞来峰|广东话|富人|风头|夺走|不介意|心态|赔偿|额外|付给|同意|杰克逊|穷人|儿歌|格林童话|卡哇伊|笑容|小孩子|浣溪沙|行放|骊歌|李一桐|交谈|全部歌曲|螺号|说用|篮球|吃饭|黄河|保卫|奶奶|无期|卫诗|莱|三月 ...

# %%
# 关键词
import re

# 定义正则表达式规则
patt闹erns = {
    "Travel-Query": r"(旅行|预订|导游|旅游|机票)",
    "Music-Play": music_pattern,
    "FilmTele-Play": r"(看电影|电影|电视剧|播放电影)",
    "Video-Play": r"(视频|播放视频|看视频)",
    "Radio-Listen": r"(收听广播|广播|电台)",
    "HomeAppliance-Control": r"(开关灯|调温度|家电控制)",
    "Weather-Query": r"(天气如何|天气预报|温度|气象)",
    "Alarm-Update": r"(设定闹钟|更新闹钟|钟)",
    "Calendar-Query": r"(日程|日历查询|安排)",
    "TVProgram-Play": r"(看电视|电视节目|播放电视节目)",
    "Audio-Play": r"(播放音频|听书|有声书)",
    "Other": r"(其他|未分类)"
}

def classify_text(text, patterns):
    text = re.sub(r'[^\w\s]', '', text.lower())  # 去除标点，转换为小写
    for category, pattern in patterns.items():
        if re.search(pattern, text):
            return category
    return "Other"  # 如果都不匹配，则归为其他


i =0  
for text in train_data[:10][0].tolist()  : 
    i += 1 
    category = classify_text(text, patterns) 
    print(f"文本：{text},分类为：{category},true-label:{train_data.loc[i,1]}")
# Out:
# 文本：还有双鸭山到淮阴的汽车票吗13号的,分类为：Other,true-label:Travel-Query
# 文本：从这里怎么回家,分类为：Music-Play,true-label:Music-Play
# 文本：随便播放一首专辑阁楼里的佛里的歌,分类为：Music-Play,true-label:FilmTele-Play
# 文本：给看一下墓王之王嘛,分类为：Other,true-label:Video-Play
# 文本：我想看挑战两把s686打突变团竞的游戏视频,分类为：Music-Play,true-label:Video-Play
# 文本：我想看和平精英上战神必备技巧的游戏视频,分类为：Music-Play,true-label:Video-Play
# 文本：2019年古装爱情电视剧小女花不弃的花絮播放一下,分类为：Music-Play,true-label:FilmTele-Play
# 文本：找一个2004年的推理剧给我看一会呢,分类为：Music-Play,true-label:Travel-Query
# 文本：自驾游去深圳都经过那些地方啊,分类为：Music-Play,true-label:Video-Play
# 文本：给我转播今天的女子双打乒乓球比赛现场,分类为：Music-Play,true-label:Music-Play

# %% [markdown]
# # 任务3：TFIDF提取与分类
# TFIDF（词频-逆文档频率）是一种常见的文本表示方法，可以用于文本分类任务。TFIDF将文本表示为词项的权重向量，其中每个词项的权重由其在文本中出现的频率和在整个语料库中出现的频率共同决定。TFIDF可以反映出词项在文本中的重要程度，越是常见的词项权重越低，越是稀有的词项权重越高。
#
# - 步骤1：使用sklearn中的TfidfVectorizer类提取训练集和测试集的特征，
# - 步骤2：使用KNN/LR/SVM等分类器对训练集进行训练，并对验证集和测试集进行预测，评估模型的性能。
# - 步骤3：通过上述步骤，请回答下面问题
#     - max_df: 用于过滤掉高频词项，在[0.0, 1.0]之间表示比例；
#      -min_df: 用于过滤掉低频词项，在[0.0, 1.0]之间表示比例；
#     - max_features: 用于限制提取特征的数量，默认为None。
#     - ngram_range: 用于指定提取n元语法特征时n值范围，默认为(1, 1)，即只提取单个词项。
#     - stop_words: 用于指定停用词列表，默认为None。
#     - norm: 用于指定归一化方法，默认为’l2’范数。
#     - use_idf: 是否使用逆文档频率计算权重，默认为True。
#     - smooth_idf: 是否平滑逆文档频率计算，默认为True
#     - TFIDF中可以设置哪些参数，如何影响到提取的特征？TfidfVectorizer类中可以设置以下参数：
#     - KNN/LR/SVM的精度对比：根据实验结果，比较三种分类器在验证集和测试集上预测正确率、召回率、F1值等指标，并分析各自优缺点。
